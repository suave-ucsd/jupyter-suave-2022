# %% [markdown]
# # SuAVE Image to Label CNN Prediction Model

# %%
# %%javascript
# function getQueryStringValue (key)
# {
#     return unescape(window.location.search.replace(new RegExp("^(?:.*[&\\?]" + escape(key).replace(/[\.\+\*]/g, "\\$&") + "(?:\\=([^&]*))?)?.*$", "i"), "$1"));
# }
# IPython.notebook.kernel.execute("survey_url='".concat(getQueryStringValue("surveyurl")).concat("'"));
# IPython.notebook.kernel.execute("user='".concat(getQueryStringValue("user")).concat("'"));
# IPython.notebook.kernel.execute("csv_file='".concat(getQueryStringValue("csv")).concat("'"));
# IPython.notebook.kernel.execute("dzc_file='".concat(getQueryStringValue("dzc")).concat("'"));
# IPython.notebook.kernel.execute("params='".concat(getQueryStringValue("params")).concat("'"));
# IPython.notebook.kernel.execute("active_object='".concat(getQueryStringValue("activeobject")).concat("'"));

# %% [markdown]
# ### Import all packages (this might take a few seconds)

# %%
import warnings
warnings.filterwarnings('ignore')  # "error", "ignore", "always", "default", "module" or "once"
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from imutils import paths

from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras import backend as K
from lenet import LeNet

# More imports
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import csv
import pandas as pd
import re
import cv2
import os

# import the necessary packages for SVM predictor
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import imutils

# Import widget functionality
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# ## Initializing the number of times the model will loop and its batch size for learning

# %%
epochCount = {
    '25 Iterations': 25,
    '50 Iterations': 50,
    '75 Iterations': 75
}

def f(epoch_count):
    return epoch_count

epochNum = interact(f, epoch_count=epochCount)
# Out:
# interactive(children=(Dropdown(description='epoch_count', options={'25 Iterations': 25, '50 Iterations': 50, '…

# %%
batchS = {
    '32 Batch Size': 32,
    '64 Batch Size': 64,
    '128 Batch Size': 128
}

def f(batch_size):
    return batch_size

batchNum = interact(f, batch_size=batchS)
# Out:
# interactive(children=(Dropdown(description='batch_size', options={'64 Batch Size': 64, '32 Batch Size': 32, '1…

# %%
# init the number of epochs to train for, init learning rate and batch size
EPOCHS = epochNum.widget.result
INIT_LR = 1e-3
BS = batchNum.widget.result
# init the image suffix, yset, and image list
suffix = '.jpg'
img_list = []
yset = []
# create labels list and 2 dicts for 2 way mapping
labels = []
# key = label value = number
label_yval = dict()
# key = number value = label
yval_label = dict()

# %% [markdown]
# ## Run and choose the column name that coresponds with the column label to be predicted

# %%
# use csv file to grab images/labels
csv_path = "../../temp_csvs/" + csv_file
df = pd.read_csv(csv_path)

#generate image path
lower_case_csv = csv_file.lower()
img_path = "../../images/" + lower_case_csv.split(".")[0]

# Choose column of label for prediction
toPredict = list(df.columns.values)

pred_menu = {}
for i in range(0, len(toPredict)):
    pred_menu[toPredict[i]] = toPredict[i]

def f(predictions_menu):
    return predictions_menu
# choose which label for predictions
out2 = interact(f, predictions_menu=pred_menu)
# Out:
# interactive(children=(Dropdown(description='predictions_menu', options={'#name': '#name', 'Title': 'Title', '#…

# %%
# iz testing; ignore
# !ls ../../images
# Out:
# cropped_butterfly_images  zaslavsk_butterfly_images
# cyclops_cave_images	  zaslavsk_cyclops_cave_ceramic_petrography
# kommos_images		  zaslavsk_kommos_ceramic_petrography
# nnegev_images		  zaslavsk_nnegev_images

# %%
# iz testing; ignore

img_path = "../../images/" + "zaslavsk_butterfly_images"
nameCol = df['#img']
predCol = df[out2.widget.result]
for i in range (0,len(nameCol)):
    base_filename = nameCol[i]
    fileName = os.path.join(img_path, base_filename + suffix)
#     print(fileName)
    if os.path.exists(fileName):
        print(fileName)
# Out:
# ../../images/zaslavsk_butterfly_images/IMG_3238_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3238_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3238_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3238_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3238_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3238_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3239_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3240_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3241_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3242_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3243_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3244_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3246_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3247_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3247_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3247_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3248_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3249_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3252_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3253_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3254_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3255_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3256_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3257_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3258_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3259_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3260_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3260_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3260_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3260_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3261_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3262_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3263_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3263_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3264_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3265_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3266_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3268_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3269_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3270_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3271_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3271_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3271_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3271_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3271_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3272_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3272_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3272_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3272_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3273_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3274_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3275_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3275_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3275_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3275_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3275_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3276_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3278_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3278_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3278_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3279_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3280_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3281_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3283_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3283_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3283_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3283_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3284_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3285_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3285_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3285_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3285_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3286_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3286_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3286_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3286_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3286_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3287_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3287_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3287_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3287_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3288_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3288_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3288_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3288_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3289_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3289_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3291_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3292_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3292_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3292_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3292_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3293_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3293_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3293_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3293_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3293_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3294_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3294_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3294_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3294_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3294_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3295_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3295_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3295_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3295_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3296_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3297_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3298_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3299_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3299_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3299_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3299_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3299_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3300_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3300_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3300_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3300_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3300_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3301_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3301_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3301_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3301_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3301_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3302_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3302_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3303_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3304_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3304_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3304_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3304_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3305_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3306_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3307_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3308_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3308_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3308_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3308_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3309_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3310_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3311_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3311_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3312_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3313_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3314_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3315_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3316_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3317_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3317_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3318_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3319_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3320_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3321_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3322_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3323_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3323_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3323_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3323_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3324_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3325_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3326_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3327_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3328_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3329_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3330_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3331_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3332_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3333_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3334_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3335_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3336_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3337_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3337_19.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3337_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3337_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3338_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3339_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3340_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3340_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3340_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3341_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3342_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3343_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3344_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3345_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3346_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_1.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_12.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_2.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3347_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_10.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_11.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3348_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3349_5.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3349_6.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3349_7.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3349_8.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3349_9.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3350_3.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3350_4.jpg
# ../../images/zaslavsk_butterfly_images/IMG_3350_5.jpg

# %% [markdown]
# ## Grab the images and configure them for predicting

# %% [markdown]
# ### This might take a little while depending on the size of the dataset

# %%
# grab chosen column names
nameCol = df['#img']
predCol = df[out2.widget.result]

# add all fabric columns to the y set
for i in range (0,len(predCol)):
    labels.append(predCol[i])

# grab all unique labels
uni_labels = set(labels)
uni_labels = list(uni_labels)

# assign each label a dict key number
for i in range(0,len(uni_labels)):
    yval_label[i] = uni_labels[i]
    label_yval[uni_labels[i]] = i

# create list of keys associated with their labels
for i in range (0, len(labels)):
    yset.append(label_yval[labels[i]])
    
# gather images from path created from file names in csv file
for i in range (0,len(nameCol)):
    base_filename = nameCol[i]
    fileName = os.path.join(img_path, base_filename + suffix)
    im = cv2.imread(fileName)
    im = cv2.resize(im, (28,28))
    im = img_to_array(im)
    img_list.append(im)

# Shuffle the data
p = np.random.permutation(len(yset))

# Relable for splitting sets
Y = []
X = []
for i in range(0,len(yset)):
    Y.append(yset[p[i]])
    X.append(img_list[p[i]])
    
# split the test and training set 75:25
split = int(len(X)*(.75))
xtrain = X[:split]
xtest = X[split:]
ytrain = Y[:split]
ytest = Y[split:]

# transform to arrays
trainX = np.array(xtrain, dtype="float")/225.0
testX = np.array(xtest, dtype ="float")/225.0

ytrain = np.array(ytrain)
ytest = np.array(ytest)

# parsed Y data containers
trainY = []
testY = []

# convert labels from int to vectors
trainY = np_utils.to_categorical(ytrain,len(uni_labels))
testY = np_utils.to_categorical(ytest,len(uni_labels))

# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,
                        height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                        horizontal_flip=True, fill_mode="nearest")
# initialize the model
model = LeNet.build(width=28, height=28, depth=3, classes=len(uni_labels))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
                metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-237-0495c2a933da> in <module>()
#      37 for i in range(0,len(yset)):
#      38     Y.append(yset[p[i]])
# ---> 39     X.append(img_list[p[i]])
#      40
#      41 # split the test and training set 75:25
#
# IndexError: list index out of range

# %% [markdown]
# ## Train the predictive model

# %% [markdown]
# ### This is relative to the size of the data set and may take a few minutes

# %%
# train the network
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=BS),
    validation_data=(testX, testY), steps_per_epoch=len(trainX) // BS,
    epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/75
# 4/4 [==============================] - 3s 745ms/step - loss: 2.8694 - acc: 0.1444 - val_loss: 2.8015 - val_acc: 0.2159
# Epoch 2/75
# 4/4 [==============================] - 3s 710ms/step - loss: 2.7861 - acc: 0.2031 - val_loss: 2.8074 - val_acc: 0.1477
# Epoch 3/75
# 4/4 [==============================] - 2s 586ms/step - loss: 2.5043 - acc: 0.1980 - val_loss: 3.1462 - val_acc: 0.1705
# Epoch 4/75
# 4/4 [==============================] - 2s 558ms/step - loss: 2.8021 - acc: 0.2005 - val_loss: 2.7582 - val_acc: 0.2614
# Epoch 5/75
# 4/4 [==============================] - 2s 583ms/step - loss: 2.7450 - acc: 0.1869 - val_loss: 2.7785 - val_acc: 0.1477
# Epoch 6/75
# 4/4 [==============================] - 2s 561ms/step - loss: 2.6399 - acc: 0.1856 - val_loss: 2.9870 - val_acc: 0.1705
# Epoch 7/75
# 4/4 [==============================] - 2s 585ms/step - loss: 2.4898 - acc: 0.2896 - val_loss: 3.0050 - val_acc: 0.1705
# Epoch 8/75
# 4/4 [==============================] - 2s 540ms/step - loss: 2.6369 - acc: 0.2005 - val_loss: 2.7495 - val_acc: 0.1705
# Epoch 9/75
# 4/4 [==============================] - 3s 725ms/step - loss: 2.6152 - acc: 0.2227 - val_loss: 2.8979 - val_acc: 0.1705
# Epoch 10/75
# 4/4 [==============================] - 2s 618ms/step - loss: 2.5791 - acc: 0.3788 - val_loss: 2.8980 - val_acc: 0.2045
# Epoch 11/75
# 4/4 [==============================] - 2s 580ms/step - loss: 2.6254 - acc: 0.2516 - val_loss: 2.6692 - val_acc: 0.2500
# Epoch 12/75
# 4/4 [==============================] - 2s 606ms/step - loss: 2.5634 - acc: 0.2789 - val_loss: 2.8386 - val_acc: 0.1818
# Epoch 13/75
# 4/4 [==============================] - 2s 587ms/step - loss: 2.5043 - acc: 0.2640 - val_loss: 2.8948 - val_acc: 0.1932
# Epoch 73/75
# 4/4 [==============================] - 2s 559ms/step - loss: 1.7495 - acc: 0.4534 - val_loss: 3.3875 - val_acc: 0.2500
# Epoch 74/75
# 4/4 [==============================] - 2s 578ms/step - loss: 1.7840 - acc: 0.4327 - val_loss: 3.7061 - val_acc: 0.2273
# Epoch 75/75
# 4/4 [==============================] - 2s 557ms/step - loss: 1.6764 - acc: 0.4724 - val_loss: 2.8437 - val_acc: 0.2500

# %% [markdown]
# ## Take the original data and predict based on the model

# %%
# Reshape original input data images for predicting
img_check = np.array(img_list, dtype ="float")/225.0

predictionsMade = []
preds = model.predict(img_check)

# Run all data through the prediction model that was created
for i in range (0,len(img_check)):
    predIndex = np.where(preds[i] == np.amax(preds[i]))
    prediction = int(predIndex[0][0])
    predictionsMade.append(prediction)
    
# Count how many correct predictions were made
correct = 0
for i in range (0,len(predictionsMade)):
    if(predictionsMade[i] == yset[i]):
        correct += 1 
        
print("Accuracy: " + str(correct/len(yset)))
# Out:
# Accuracy: 0.3721590909090909

# %%
#Generate model file and save
modelName = user + "_cnn_" + out2.widget.result + "_" + str(epochNum.widget.result) + "_" + str(batchNum.widget.result) + ".h5"
modelPath = "models/"

model.save(os.path.join(modelPath, modelName))

# %%
#Load model
from keras.models import load_model
model2 = load_model(os.path.join(modelPath, modelName))

# %%
predictionsMade
# Out:
# [10,
#  9,
#  10,
#  9,
#  10,
#  9,
#  10,
#  9,
#  5,
#  10,
#  12,
#  10,
#  10,
#  21,
#  9,
#  9,
#  10,
#  19,
#  9,
#  9,
#  10,
#  21,
#  10,
#  10,
#  12,
#  9,
#  9,
#  9,
#  9,
#  21,
#  10,
#  10,
#  12,
#  9,
#  12,
#  9,
#  12,
#  10,
#  12,
#  18,
#  9,
#  9,
#  9,
#  9,
#  10,
#  3,
#  10,
#  10,
#  12,
#  5,
#  9,
#  12,
#  10,
#  21,
#  9,
#  9,
#  10,
#  10,
#  10,
#  21,
#  9,
#  9,
#  9,
#  9,
#  10,
#  10,
#  9,
#  10,
#  10,
#  21,
#  10,
#  10,
#  10,
#  9,
#  21,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  9,
#  9,
#  21,
#  21,
#  9,
#  9,
#  12,
#  21,
#  18,
#  21,
#  10,
#  21,
#  9,
#  9,
#  12,
#  9,
#  9,
#  9,
#  10,
#  21,
#  9,
#  9,
#  10,
#  21,
#  21,
#  9,
#  10,
#  21,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  10,
#  10,
#  12,
#  9,
#  10,
#  21,
#  10,
#  10,
#  9,
#  9,
#  9,
#  12,
#  10,
#  3,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  3,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  6,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  17,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  3,
#  10,
#  21,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  17,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  21,
#  10,
#  21,
#  10,
#  10,
#  10,
#  10,
#  12,
#  10,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  3,
#  10,
#  10,
#  10,
#  10,
#  10,
#  18,
#  10,
#  17,
#  10,
#  10,
#  10,
#  17,
#  10,
#  10,
#  12,
#  10,
#  12,
#  10,
#  10,
#  10,
#  10,
#  10,
#  12,
#  10,
#  10,
#  10,
#  12,
#  3,
#  10,
#  10,
#  10,
#  10,
#  18,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  3,
#  10,
#  10,
#  12,
#  10,
#  12,
#  12,
#  10,
#  10,
#  18,
#  9,
#  12,
#  9,
#  12,
#  12,
#  12,
#  10,
#  18,
#  12,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  18,
#  10,
#  12,
#  10,
#  10,
#  10,
#  9,
#  10,
#  12,
#  12,
#  10,
#  3,
#  10,
#  10,
#  10,
#  1,
#  9,
#  12,
#  10,
#  10,
#  10,
#  10,
#  12,
#  12,
#  9,
#  12,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  12,
#  10,
#  10,
#  12,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  17,
#  10,
#  10,
#  10,
#  3,
#  10,
#  3,
#  12,
#  10,
#  12,
#  12,
#  10,
#  21,
#  10,
#  10,
#  10,
#  10,
#  10,
#  21]

# %% [markdown]
# ## Enter a new header for the prediction column

# %%
# Translate back to original csv label names
finalPred = []
for i in range (0,len(predictionsMade)):
    finalPred.append(yval_label[predictionsMade[i]])

from IPython.display import display
input_text = widgets.Text(
    value=None,
    placeholder='Type label here',
    disabled=False
)
output_text = widgets.Text(
    value=None,
    placeholder='New Header will be displayed here',
    disabled=False
)

def bind_input_to_output(sender):
    output_text.value = input_text.value

input_text.observe(bind_input_to_output)

print("Input new column Header Label: ")

display(input_text)
display(output_text)
# Out:
# Input new column Header Label:
# Text(value='', placeholder='Type label here')
# Text(value='', placeholder='New Header will be displayed here')

# %% [markdown]
# ## Write the predictions back to the original CSV

# %%
# Append the new column w/ it's new column name
df[input_text.value] = finalPred
print(input_text.value)

# new file name
new_file =  csv_file[:-4]+'_v1.csv'
df.to_csv(new_file, index=None)
# Out:
# kommos_j_test_1

# %%
#Input survey name

from IPython.display import display
input_text = widgets.Text()
output_text = widgets.Text()

def bind_input_to_output(sender):
    output_text.value = input_text.value

# Tell the text input widget to call bind_input_to_output() on submit
input_text.observe(bind_input_to_output)

print("Input survey name here:")
# Display input text box widget for input
display(input_text)

display(output_text)

survey_name = output_text.value
# Out:
# Input survey name here:
# Text(value='')
# Text(value='')

# %%
print(input_text.value)
print(dzc_file)
# Out:
# kommos_j_test_1
# https://bioregional.ucsd.edu/suave/surveys/kommos_Oct2017/kommos_Oct2017.dzc

# %%
import requests
upload_url = "http://suave.sdsc.edu:3001/uploadCSV"
upload_data = {'name': input_text.value, 'dzc': dzc_file, 'user':user}
files = {"file": open(new_file, "rb")}
r = requests.post(upload_url, files=files, data=upload_data)
print(r.status_code, r.reason)

regex = re.compile('[^0-9a-zA-Z_]')
survey_url = survey_name
survey_url =  regex.sub('_', survey_url)

url = "https://suave-dev.sdsc.edu/main/file=" + user + "_" + input_text.value + ".csv" + "&views=1110001&view=grid"
print(url)
# Out:
# 200 OK
# https://suave-dev.sdsc.edu/main/file=zaslavsk_.csv&views=1110001&view=grid
